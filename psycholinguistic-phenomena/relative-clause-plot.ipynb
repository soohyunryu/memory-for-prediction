# %% [markdown]
# This notebook is for generation Figure 7.

# %%
import pandas as pd
import numpy as np
from metrics import *
from bertviz import head_view

# %%
orc = "Yesterday, the girl who the parents watched changed a critical part of the story"
src = "Yesterday at noon, the girl who watched the parents changed a critical part of the story"

# %%
inputs = tokenizer.encode(orc, return_tensors='pt')
tokens = tokenizer.convert_ids_to_tokens(inputs[0]) 
outputs = model(inputs)
attention = outputs[-1]  # Output includes attention weights when output_attentions=True
head_view(attention, tokens, layer = 4, heads= [3])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-1beee2b65dbf4778a622e6c1c459e7e8" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
inputs = tokenizer.encode(src, return_tensors='pt')
tokens = tokenizer.convert_ids_to_tokens(inputs[0]) 
outputs = model(inputs)
attention = outputs[-1]  # Output includes attention weights when output_attentions=True
head_view(attention, tokens, layer = 4, heads= [3])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-12d4aecd91184816a73ea005bf4331d9" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
